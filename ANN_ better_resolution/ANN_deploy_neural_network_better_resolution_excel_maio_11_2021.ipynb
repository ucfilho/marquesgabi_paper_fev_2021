# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/marquesgabi_paper_fev_2021/blob/main/ANN_%20better_resolution/ANN_deploy_neural_network_better_resolution_excel_maio_11_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import zipfile
#import random
from random import randint
from PIL import Image
import re
from sklearn.model_selection import train_test_split
#import scikit-image
import skimage
import pandas as pd
#import statsmodels.api as sm
#import statsmodels.formula.api as smf
from sklearn.neural_network import MLPClassifier
import sklearn
from sklearn.externals import joblib
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
# !git clone https://github.com/ucfilho/MarquesGabi_Routines
# %cd MarquesGabi_Routines
# Out:
# fatal: destination path 'MarquesGabi_Routines' already exists and is not an empty directory.
# /content/MarquesGabi_Routines

# %%
# leitura dos dados
df1=pd.read_excel("ImgGrao_a.xlsx")
df2=pd.read_excel("ImgGrao_b.xlsx")
df3=pd.read_excel("ImgIndef.xlsx")
df4=pd.read_excel("ImgVarios.xlsx")
df5=pd.read_excel("ImgBuraco.xlsx")

# %%
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
df.head()
# Out:
#    Unnamed: 0         0         1         2  ...      9997      9998      9999  Type
# 0           0  0.000000  0.000000  0.000000  ...  0.690648  0.692724  0.695607     G
# 1           1  0.590733  0.590733  0.593513  ...  0.548059  0.551222  0.550831     G
# 2           2  0.782922  0.567252  0.436217  ...  0.695368  0.688670  0.690964     G
# 3           3  0.755803  0.743160  0.726090  ...  0.422302  0.419027  0.427234     G
# 4           4  0.393078  0.386396  0.379635  ...  0.618702  0.607442  0.600833     G
#
# [5 rows x 10002 columns]

# %%
# rede 1 G e B --> r1
# rede 2 G e I --> r2
# rede 3 G e V --> r3

df_r1 = pd.concat([df1, df2, df3, df5], ignore_index=True)
df_r2 = pd.concat([df1, df2, df3], ignore_index=True)
df_r3 = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
w = df['Type']
y = []
for wi in w:
  if(wi == 'G'):
    y.append(1)
  elif(wi == 'B'):
    y.append(2)
  elif(wi == 'I'):
    y.append(3)
  elif(wi == 'V'):
    y.append(4)

# %%
w = df_r1['Type']
y_r1 = []
for wi in w:
  if(wi == 'G'):
    y_r1.append(1)
  elif(wi == 'B'):
    y_r1.append(2)
  elif(wi == 'I'):
    y_r1.append(3)
  elif(wi == 'V'):
    y_r1.append(4)

# %%
w = df_r2['Type']
y_r2 = []
for wi in w:
  if(wi == 'G'):
    y_r2.append(1)
  elif(wi == 'B'):
    y_r2.append(2)
  elif(wi == 'I'):
    y_r2.append(3)
  elif(wi == 'V'):
    y_r2.append(4)

# %%
w = df_r3['Type']
y_r3 = []
for wi in w:
  if(wi == 'G'):
    y_r3.append(1)
  elif(wi == 'B'):
    y_r3.append(2)
  elif(wi == 'I'):
    y_r3.append(3)
  elif(wi == 'V'):
    y_r3.append(4)

# %%
df_r1.drop(['Unnamed: 0','Type'], axis='columns', inplace=True)
df_r2.drop(['Unnamed: 0','Type'], axis='columns', inplace=True)
df_r3.drop(['Unnamed: 0','Type'], axis='columns', inplace=True)

# %%
df.drop(['Unnamed: 0','Type'], axis='columns', inplace=True)

# %%
df.head()
# Out:
#        0         1         2     ...      9997      9998      9999
# 0  0.000000  0.000000  0.000000  ...  0.690648  0.692724  0.695607
# 1  0.590733  0.590733  0.593513  ...  0.548059  0.551222  0.550831
# 2  0.782922  0.567252  0.436217  ...  0.695368  0.688670  0.690964
# 3  0.755803  0.743160  0.726090  ...  0.422302  0.419027  0.427234
# 4  0.393078  0.386396  0.379635  ...  0.618702  0.607442  0.600833
#
# [5 rows x 10000 columns]

# %%
#X =np.array(df.copy())/255.0 
X =np.array(df.copy())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, shuffle=True, random_state=42)

model = MLPClassifier(hidden_layer_sizes=(200,10), activation='tanh', 
                      solver='adam',random_state=1, max_iter=300).fit(X_train,y_train)
  
prediction = model.predict(X_test)
  
y =np.copy(y_test)
data = {'y_true': y_test,'y_predict': prediction}  # este dado esta no formato de dicionario

df = pd.DataFrame(data, columns=['y_true','y_predict'])


confusion_matrix = pd.crosstab(df['y_true'], df['y_predict'], rownames=['Actual'], colnames=['Predict'])
print(confusion_matrix)

y_true = df['y_true']
y_pred = df['y_predict']

  
METRICS=sklearn.metrics.classification_report(y_true, y_pred)
# Out:
# Predict    1   2  3  4
# Actual
# 1        105   1  0  0
# 2          0  51  0  0
# 3         20  40  3  0
# 4         26  15  3  1

# %%
#X =np.array(df.copy())/255.0 
df = df_r1.copy()
y = y_r1.copy()
X =np.array(df.copy())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, shuffle=True, random_state=42)

model = MLPClassifier(hidden_layer_sizes=(200,10), activation='tanh', 
                      solver='adam',random_state=1, max_iter=300).fit(X_train,y_train)
  
prediction = model.predict(X_test)
  
y =np.copy(y_test)
data = {'y_true': y_test,'y_predict': prediction}  # este dado esta no formato de dicionario

df = pd.DataFrame(data, columns=['y_true','y_predict'])


confusion_matrix = pd.crosstab(df['y_true'], df['y_predict'], rownames=['Actual'], colnames=['Predict'])
print('rede 1 G e B --> r1') 
print(confusion_matrix)

y_true = df['y_true']
y_pred = df['y_predict']

  
METRICS=sklearn.metrics.classification_report(y_true, y_pred)
# Out:
# rede 1 G e B --> r1
# Predict    1  2   3
# Actual
# 1        114  3   2
# 2          1  0  46
# 3          5  4  41

# %%
#X =np.array(df.copy())/255.0 
df = df_r2.copy()
y = y_r2.copy()
X =np.array(df.copy())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, shuffle=True, random_state=42)

model = MLPClassifier(hidden_layer_sizes=(200,10), activation='tanh', 
                      solver='adam',random_state=1, max_iter=300).fit(X_train,y_train)
  
prediction = model.predict(X_test)
  
y =np.copy(y_test)
data = {'y_true': y_test,'y_predict': prediction}  # este dado esta no formato de dicionario

df = pd.DataFrame(data, columns=['y_true','y_predict'])


confusion_matrix = pd.crosstab(df['y_true'], df['y_predict'], rownames=['Actual'], colnames=['Predict'])
print(' rede 2 G e I --> r2')
print(confusion_matrix)

y_true = df['y_true']
y_pred = df['y_predict']

  
METRICS=sklearn.metrics.classification_report(y_true, y_pred)
# Out:
#  rede 2 G e I --> r2
# Predict    1
# Actual
# 1        106
# 3         56
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#X =np.array(df.copy())/255.0 
df = df_r3.copy()
y = y_r3.copy()
X =np.array(df.copy())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, shuffle=True, random_state=42)

model = MLPClassifier(hidden_layer_sizes=(200,10), activation='tanh', 
                      solver='adam',random_state=1, max_iter=300).fit(X_train,y_train)
  
prediction = model.predict(X_test)
  
y =np.copy(y_test)
data = {'y_true': y_test,'y_predict': prediction}  # este dado esta no formato de dicionario

df = pd.DataFrame(data, columns=['y_true','y_predict'])


confusion_matrix = pd.crosstab(df['y_true'], df['y_predict'], rownames=['Actual'], colnames=['Predict'])
print('rede 3 G e V --> r3')
print(confusion_matrix)

y_true = df['y_true']
y_pred = df['y_predict']

  
METRICS=sklearn.metrics.classification_report(y_true, y_pred)
# Out:
# rede 3 G e V --> r3
# Predict    1
# Actual
# 1        121
# 3         48
# 4         42
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
joblib.dump(model,'model_ANN_new.pkl')
# Out:
# ['model_ANN_new.pkl']

# %%
Arq = 'model_ANN_new.pkl'
from google.colab import files
files.download(Arq)
